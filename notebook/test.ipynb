# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

# %%
a = pd.read_csv('/config/workspace/prediction/MLP_training_dataset05192023__114610.csv')

# %%
a
# Out:
#        Unnamed: 0       txId  time step  transaction_feature_1
# 0               0  232438397          1               0.163054  \
# 1               1  232029206          1              -0.005027
# 2               2  232344069          1              -0.147852
# 3               3   27553029          1              -0.151357
# 4               4    3881097          1              -0.172306
# ...           ...        ...        ...                    ...
# 46559       46559   80329479         49              -0.159293
# 46560       46560  158406298         49              -0.172962
# 46561       46561  158375075         49              -0.170412
# 46562       46562  147478192         49              -0.093732
# 46563       46563  158375402         49              -0.172014
#
#        transaction_feature_2  transaction_feature_3  transaction_feature_4
# 0                   1.963790              -0.646376              12.409294  \
# ...

# %%
y_train = a['class']
yhat_train = a['cat_pred']

# %%
yhat_train.shape
# Out:
# (46564,)

# %%
accuracy_score(y_train, yhat_train)
# Out:
# 0.9959840219912378
